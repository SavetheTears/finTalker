# %%
import pandas as pd

df = pd.read_csv('./courses_with_skills.csv')
df
# Out:
#      Unnamed: 0                                     Course_Name
# 0             0            Introduction to financial accounting  \
# 1             1              Professional preparation programme
# 2             2                     Introductory microeconomics
# 3             3                     Introductory macroeconomics
# 4             4                       Analysis of economic data
# ..          ...                                             ...
# 213         213  Applications of strategic thinking in business
# 214         214                Competitiveness of Chinese firms
# 215         215                            Strategic management
# 216         216                       Global corporate strategy
# 217         217                       Business in Latin America
#
#                                     Course_Description
# 0    cover the principles of double entry book-keep...  \
# 1    prepare students for a career in professional ...
# ...

# %%
for i in range(len(df)):
    ans_soft = df.Course_Soft_Skills[i]
    if ans_soft == None:
        continue
    stemmer = ans_soft.split()
    if stemmer[0] == 'No' or stemmer[0] == 'no.':
        df.Course_Soft_Skills[i] = None
        continue
        
for i in range(len(df)):
    ans_hard = df.Course_Hard_Skills[i]
    if ans_hard == None:
        continue
    stemmer = ans_hard.split()
    if stemmer[0] == 'No' or stemmer[0] == 'no.':
        df.Course_Hard_Skills[i] = None
        continue

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
    print(df.Course_Soft_Skills)
# Out:
# 0                                                   None
# 1      Developing interpersonal, communication and ti...
# 2      Developing ethics and public policy. (Soft ski...
# 3                                                   None
# 4                                                   None
# 5      Incorporating corporate ethics in financial de...
# 6      Developing awareness of management processes, ...
# 7      Managing customer relationships. (Soft skills ...
# 8                                                   None
# 9                                                   None
# 10                                                  None
# 11                                                  None
# 12                                                  None
# 13     Soft skills mentioned: Professional ethics, so...
# 14            Soft skills not mentioned in the sentence.
# 15            Soft skills not mentioned in the sentence.
# ...

# %%
NOT_SPECIFIED = 'Not_Specified'

# %%
for i in range(len(df)):
    ans_soft = df.Course_Soft_Skills[i]
    if ans_soft == None:
        continue
        
    if 'Soft skills not mentioned' in ans_soft or "Soft skills mentioned: No." in ans_soft or \
    'Soft skills mentioned: None' in ans_soft or 'No soft skills mentioned' in ans_soft or \
    'Soft skills mentioned: no' in ans_soft:
        df.Course_Soft_Skills[i] = None
        
    if 'but none are specified' in ans_soft:
        df.Course_Soft_Skills[i] = NOT_SPECIFIED

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
    print(df.Course_Soft_Skills)
# Out:
# 0                                                   None
# 1      Developing interpersonal, communication and ti...
# 2      Developing ethics and public policy. (Soft ski...
# 3                                                   None
# 4                                                   None
# 5      Incorporating corporate ethics in financial de...
# 6      Developing awareness of management processes, ...
# 7      Managing customer relationships. (Soft skills ...
# 8                                                   None
# 9                                                   None
# 10                                                  None
# 11                                                  None
# 12                                                  None
# 13     Soft skills mentioned: Professional ethics, so...
# 14                                                  None
# 15                                                  None
# ...

# %%
for i in range(len(df)):
    ans_hard = df.Course_Hard_Skills[i]
    if ans_hard == None:
        continue
        
    if 'Hard skills not mentioned' in ans_hard or "Hard skills mentioned: No." in ans_hard or \
    'Hard skills mentioned: None' in ans_hard or 'No hard skills mentioned' in ans_hard or \
    'Hard skills mentioned: no' in ans_hard:
        df.Course_Hard_Skills[i] = None
        
    if 'but none are specified' in ans_hard:
        df.Course_Hard_Skills[i] = NOT_SPECIFIED

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
    print(df.Course_Hard_Skills)
# Out:
# 0      Hard skills mentioned: principles of double en...
# 1                                                   None
# 2      Studying demand and supply, consumer theory, c...
# 3      Measuring macroeconomic variables, studying th...
# 4      Studying measurement and interpretation of eco...
# 5      Developing basic concepts and tools applicable...
# 6                                                   None
# 7      Understanding customers, competitors, and mark...
# 8      Reviewing financial accounting concepts, recor...
# 9      Serving the accounting needs of management, de...
# 10     Examining debt financing, equity financing, in...
# 11     Hard skills mentioned: managerial accounting, ...
# 12     Hard skills mentioned: understanding of curren...
# 13     Hard skills mentioned: Auditing concepts and p...
# 14     Hard skills mentioned: Use of accounting infor...
# 15     Hard skills mentioned: Knowledge of accounting...
# ...

# %%
# delete over verbose word. Hard
for i in range(len(df)):
    ans_hard = df.Course_Hard_Skills[i]
    if ans_hard == None or ans_hard ==NOT_SPECIFIED:
        continue
    
    # contain :
    type_1 = df.Course_Hard_Skills[i].split(': ',1)
    if len(type_1) == 2:
        df.Course_Hard_Skills[i] = type_1[1]
        continue
        
    # 'include'
    type_2 = df.Course_Hard_Skills[i].split('include ',1)
    if len(type_2) == 2:
        df.Course_Hard_Skills[i] = type_2[1]
        continue
    
    # -
    type_3  = df.Course_Hard_Skills[i].split('- ',1)
    if len(type_3) == 2:
        df.Course_Hard_Skills[i] = type_3[1]
        continue

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
    print(df.Course_Hard_Skills)
# Out:
# 0      principles of double entry book-keeping, inter...
# 1                                                   None
# 2      Studying demand and supply, consumer theory, c...
# 3      Measuring macroeconomic variables, studying th...
# 4      Studying measurement and interpretation of eco...
# 5      Developing basic concepts and tools applicable...
# 6                                                   None
# 7      Understanding customers, competitors, and mark...
# 8      Reviewing financial accounting concepts, recor...
# 9      Serving the accounting needs of management, de...
# 10     Examining debt financing, equity financing, in...
# 11     managerial accounting, management information ...
# 12     understanding of current law, principles and p...
# 13     Auditing concepts and principles, evidence gat...
# 14     Use of accounting information, internal contro...
# 15     Knowledge of accounting information systems, b...
# ...

# %%
# delete over verbose word. Soft
for i in range(len(df)):
    ans_soft = df.Course_Soft_Skills[i]
    if ans_soft == None or ans_soft ==NOT_SPECIFIED:
        continue
    
    # contain :
    type_1 = df.Course_Soft_Skills[i].split(': ',1)
    if len(type_1) == 2:
        df.Course_Soft_Skills[i] = type_1[1]
        continue
        
    # 'include'
    type_2 = df.Course_Soft_Skills[i].split('include ',1)
    if len(type_2) == 2:
        df.Course_Soft_Skills[i] = type_2[1]
        continue
    
    # -
    type_3  = df.Course_Soft_Skills[i].split('- ',1)
    if len(type_3) == 2:
        df.Course_Soft_Skills[i] = type_3[1]
        continue
        
with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
    print(df.Course_Soft_Skills)
# Out:
# 0                                                   None
# 1      Developing interpersonal, communication and ti...
# 2      Developing ethics and public policy. (Soft ski...
# 3                                                   None
# 4                                                   None
# 5      Incorporating corporate ethics in financial de...
# 6      Developing awareness of management processes, ...
# 7      Managing customer relationships. (Soft skills ...
# 8                                                   None
# 9                                                   None
# 10                                                  None
# 11                                                  None
# 12                                                  None
# 13     Professional ethics, social responsibility, le...
# 14                                                  None
# 15                                                  None
# ...

# %%
df
# Out:
#      Unnamed: 0                                     Course_Name
# 0             0            Introduction to financial accounting  \
# 1             1              Professional preparation programme
# 2             2                     Introductory microeconomics
# 3             3                     Introductory macroeconomics
# 4             4                       Analysis of economic data
# ..          ...                                             ...
# 213         213  Applications of strategic thinking in business
# 214         214                Competitiveness of Chinese firms
# 215         215                            Strategic management
# 216         216                       Global corporate strategy
# 217         217                       Business in Latin America
#
#                                     Course_Description
# 0    cover the principles of double entry book-keep...  \
# 1    prepare students for a career in professional ...
# ...

# %%
df
# Out:
#                                         Course_Name
# 0              Introduction to financial accounting  \
# 1                Professional preparation programme
# 2                       Introductory microeconomics
# 3                       Introductory macroeconomics
# 4                         Analysis of economic data
# ..                                              ...
# 213  Applications of strategic thinking in business
# 214                Competitiveness of Chinese firms
# 215                            Strategic management
# 216                       Global corporate strategy
# 217                       Business in Latin America
#
#                                     Course_Description
# 0    cover the principles of double entry book-keep...  \
# 1    prepare students for a career in professional ...
# 2    ntroduction to the basic concepts and principl...
# 3    first introduce students to the measurement of...
# 4    This course studies the measurement and interp...
# ...

# %%
df.to_csv('./output_cleaned.csv')

# %% [markdown]
# # Done

# %%
import pandas as pd
NOT_SPECIFIED = 'Not_Specified'

df = pd.read_csv('./output_cleaned.csv')

for i in range(len(df)):
    if pd.isna(df.Course_Soft_Skills[i]):
        df.Course_Soft_Skills[i] = None
    
    if pd.isna(df.Course_Hard_Skills[i]):
        df.Course_Hard_Skills[i] = None
# Out:
# /var/folders/rz/_bscg79j2wn4k637cwhnrgn00000gn/T/ipykernel_13336/3466185225.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.Course_Soft_Skills[i] = None
# /var/folders/rz/_bscg79j2wn4k637cwhnrgn00000gn/T/ipykernel_13336/3466185225.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.Course_Hard_Skills[i] = None
# /var/folders/rz/_bscg79j2wn4k637cwhnrgn00000gn/T/ipykernel_13336/3466185225.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
df
# Out:
#      Unnamed: 0                                     Course_Name
# 0             0            Introduction to financial accounting  \
# 1             1              Professional preparation programme
# 2             2                     Introductory microeconomics
# 3             3                     Introductory macroeconomics
# 4             4                       Analysis of economic data
# ..          ...                                             ...
# 213         213  Applications of strategic thinking in business
# 214         214                Competitiveness of Chinese firms
# 215         215                            Strategic management
# 216         216                       Global corporate strategy
# 217         217                       Business in Latin America
#
#                                     Course_Description
# 0    cover the principles of double entry book-keep...  \
# 1    prepare students for a career in professional ...
# ...

# %%
for i in range(len(df)):
    ans_soft = df.Course_Soft_Skills[i]
    if not ans_soft or ans_soft ==NOT_SPECIFIED:
        continue
        
    if ans_soft == 'no' or 'no reference in the sentence' in ans_soft:
        df.Course_Soft_Skills[i] = None
        continue
        
    if '(Soft skills mentioned)' in ans_soft:
        df.Course_Soft_Skills[i] = df.Course_Soft_Skills[i][:-23]
# Out:
# /var/folders/rz/_bscg79j2wn4k637cwhnrgn00000gn/T/ipykernel_13336/2141095550.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.Course_Soft_Skills[i] = df.Course_Soft_Skills[i][:-23]
# /var/folders/rz/_bscg79j2wn4k637cwhnrgn00000gn/T/ipykernel_13336/2141095550.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.Course_Soft_Skills[i] = df.Course_Soft_Skills[i][:-23]
# /var/folders/rz/_bscg79j2wn4k637cwhnrgn00000gn/T/ipykernel_13336/2141095550.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
a = 'i am good. (nice)'
a[:-len(' (nice)')]
# Out:
# 'i am good.'

# %%
len('(Soft skills mentioned)')
# Out:
# 23

# %%
df
# Out:
#      Unnamed: 0                                     Course_Name
# 0             0            Introduction to financial accounting  \
# 1             1              Professional preparation programme
# 2             2                     Introductory microeconomics
# 3             3                     Introductory macroeconomics
# 4             4                       Analysis of economic data
# ..          ...                                             ...
# 213         213  Applications of strategic thinking in business
# 214         214                Competitiveness of Chinese firms
# 215         215                            Strategic management
# 216         216                       Global corporate strategy
# 217         217                       Business in Latin America
#
#                                     Course_Description
# 0    cover the principles of double entry book-keep...  \
# 1    prepare students for a career in professional ...
# ...

# %%
for i in range(len(df)):
    ans_hard = df.Course_Hard_Skills[i]
    if not ans_hard or ans_hard ==NOT_SPECIFIED:
        continue
        
    if ans_hard == 'no' or 'no reference in the sentence' in ans_hard:
        df.Course_Hard_Skills[i] = None
        continue
        
    if '(Hard skills mentioned)' in ans_hard:
        df.Course_Hard_Skills[i] = df.Course_Hard_Skills[i][:-23]
# Out:
# /var/folders/rz/_bscg79j2wn4k637cwhnrgn00000gn/T/ipykernel_13336/120133159.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.Course_Hard_Skills[i] = df.Course_Hard_Skills[i][:-23]
# /var/folders/rz/_bscg79j2wn4k637cwhnrgn00000gn/T/ipykernel_13336/120133159.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.Course_Hard_Skills[i] = df.Course_Hard_Skills[i][:-23]
# /var/folders/rz/_bscg79j2wn4k637cwhnrgn00000gn/T/ipykernel_13336/120133159.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
df
# Out:
#      Unnamed: 0                                     Course_Name
# 0             0            Introduction to financial accounting  \
# 1             1              Professional preparation programme
# 2             2                     Introductory microeconomics
# 3             3                     Introductory macroeconomics
# 4             4                       Analysis of economic data
# ..          ...                                             ...
# 213         213  Applications of strategic thinking in business
# 214         214                Competitiveness of Chinese firms
# 215         215                            Strategic management
# 216         216                       Global corporate strategy
# 217         217                       Business in Latin America
#
#                                     Course_Description
# 0    cover the principles of double entry book-keep...  \
# 1    prepare students for a career in professional ...
# ...

# %%
df.Course_Soft_Skills[1]
# Out:
# 'Developing interpersonal, communication and time-management skills. '

# %%
df.to_csv('./output_cleaned.csv')
