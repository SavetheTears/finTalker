# %%
import pandas as pd
import numpy as np
df = pd.read_csv('../jobs.csv')
df.columns
# Out:
# Index(['Job Title', 'Job Description', 'Job Type', 'Categories', 'Location',
#        'City', 'State', 'Country', 'Zip Code', 'Address', 'Salary From',
#        'Salary To', 'Salary Period', 'Apply Url', 'Apply Email', 'Employees',
#        'Industry', 'Company Name', 'Employer Email', 'Employer Website',
#        'Employer Phone', 'Employer Logo', 'Companydescription',
#        'Employer Location', 'Employer City', 'Employer State',
#        'Employer Country', 'Employer Zip Code', 'Uniq Id', 'Crawl Timestamp'],
#       dtype='object')

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
df = df[['Job Title','Job Description']]

# %%
df[:300]
# Out:
#                                 Job Title  \
# 0                           Shift Manager
# 1              Operations Support Manager
# 2           Senior Product Manager - Data
# 3              Part-Time Office Concierge
# 4             Print & Marketing Associate
# ..                                    ...
# 295                                  GMIT
# 296        Manager, Business Optimization
# 297  Logistics and Dispatcher Coordinator
# 298                Senior DevOps Engineer
# 299        Sales Associate/Beauty Advisor
#
#                                        Job Description
# 0    <div id="jobDescriptionText" class="jobsearch-...
# 1    <div id="jobDescriptionText" class="jobsearch-...
# 2    <div id="jobDescriptionText" class="jobsearch-...
# 3    <div id="jobDescriptionText" class="jobsearch-...
# 4    <div id="jobDescriptionText" class="jobsearch-...
# ..                                                 ...
# 295  <div id="jobDescriptionText" class="jobsearch-...
# 296  <div id="jobDescriptionText" class="jobsearch-...
# 297  <div id="jobDescriptionText" class="jobsearch-...
# 298  <div id="jobDescriptionText" class="jobsearch-...
# 299  <div id="jobDescriptionText" class="jobsearch-...
#
# [300 rows x 2 columns]

# %%
import re
# as per recommendation from @freylis, compile once only
HTML_CLEANR = re.compile('<.*?>') 
BLANK_CLEANR = re.compile('\n')

def cleanhtml(raw_html):
  cleantext = re.sub(HTML_CLEANR, '', raw_html)
  #cleantext = re.sub('\n+', ' ',raw_html)
  return cleantext

def remove(s):
    # Pattern for matching whitespaces
    pattern=r"\s+"

    # Using re.sub() function to remove whitespaces
    s = re.sub(pattern, " ", s)
    return s

# %%
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize

from functools import reduce
 
ps = PorterStemmer()

stop_words = set(stopwords.words('english'))

# %%
df.loc[2,'Job Description']
# Out:
# '<div id="jobDescriptionText" class="jobsearch-jobDescriptionText">Product Manager - Unique opportunity with a mobile marketing leader\n<br><br>\nVibes helps brands unlock new revenue by arming them with the technology and expertise they need to succeed in mobile marketing.\n<br><br>\nWe are a group of passionate technologists, intent on solving hard problems in the evolving world of mobile engagement. We focus on collaboration and continuous improvement of our products and ourselves.\n<br><br>\nYou are a Product Manager with a passion for data and creating amazing customer experiences to connect people to the brands they love. You have experience delivering successful, data informed SaaS experiences and are excited to own our Data experience and continue making it the key differentiator of our platform. You are energized by setting a vision, experimenting to validate or invalidate assumptions, and leading a product experience team to build software that will interact with millions of people via their phones.\n<br><br>\nResponsibilities\n<br><br>\n<ul>\n<li>Define data strategy for our platform</li>\n<li>Manage product development of that strategy through lean hypotheses &amp; experimentation, defining customer experiences and journeys, owning and managing the product backlog</li>\n<li>Lead the team to take potential data, models, and outputs and integrate them into the current platform experience or potential new experiences</li>\n<li>Work with Data &amp; Analytics engineering team to build predictive and prescriptive data intelligence into our Mobile Engagement platform</li>\n<li>Collaborate with Marketing, Sales, Customer Success and Technology to understand feasibility and constraints of potential alternative solutions</li>\n<li>Communicate team\'s accomplishments upward and outward throughout organization</li>\n<li>Be a compelling market-facing voice for Vibes\' data vision and experiences</li>\n</ul>\nRequirements\n<br><br>\n<ul>\n<li>2+ years relevant product management experience, strongly preferred</li>\n<li>Ability to analyze data, write SQL, and interpret experiment results</li>\n<li>Understanding of data modeling, data infrastructure, and statistical and machine learning</li>\n<li>Ability to understand and speak the language of data scientists and data engineers to be at the leading edge of the fast moving data landscape through experience with tools such as:</li>\n<li>Modern BI / Analytics tools such as Microstrategy or Tableau</li>\n<li>R or related languages/frameworks</li>\n<li>AI and ML frameworks and tools</li>\n<li>Experience playing the product owner role of an engineering team</li>\n<li>Lean business development and customer development experience</li>\n<li>Strong written and verbal communication skills</li>\n</ul>\n<b>Our Core Values:</b><br>\n<ul>\n<li>Respect, Honesty, and Integrity for All Stakeholders</li>\n<li>Always be Learning</li>\n<li>Relentless Focus on the Customer</li>\n<li>Never be Satisfied</li>\n<li>Create Value</li>\n<li>Seek Accountability and Ownership</li>\n</ul>\nVibes is an equal opportunity employer that encourages and fosters diversity in the workplace. We offer a career building experience in a fast-paced organization and industry.</div>'

# %%
s = cleanhtml(df.loc[2,'Job Description'])
s = remove(s)
s.strip()

words = word_tokenize(s)
stemmed_sentence = reduce(lambda x, y: x + " " + ps.stem(y), words, "")
words = word_tokenize(stemmed_sentence)
' '.join(words)

s
# Out:
# "Product Manager - Unique opportunity with a mobile marketing leader Vibes helps brands unlock new revenue by arming them with the technology and expertise they need to succeed in mobile marketing. We are a group of passionate technologists, intent on solving hard problems in the evolving world of mobile engagement. We focus on collaboration and continuous improvement of our products and ourselves. You are a Product Manager with a passion for data and creating amazing customer experiences to connect people to the brands they love. You have experience delivering successful, data informed SaaS experiences and are excited to own our Data experience and continue making it the key differentiator of our platform. You are energized by setting a vision, experimenting to validate or invalidate assumptions, and leading a product experience team to build software that will interact with millions of people via their phones. Responsibilities Define data strategy for our platform Manage product development of that strategy through lean hypotheses &amp; experimentation, defining customer experiences and journeys, owning and managing the product backlog Lead the team to take potential data, models, and outputs and integrate them into the current platform experience or potential new experiences Work with Data &amp; Analytics engineering team to build predictive and prescriptive data intelligence into our Mobile Engagement platform Collaborate with Marketing, Sales, Customer Success and Technology to understand feasibility and constraints of potential alternative solutions Communicate team's accomplishments upward and outward throughout organization Be a compelling market-facing voice for Vibes' data vision and experiences Requirements 2+ years relevant product management experience, strongly preferred Ability to analyze data, write SQL, and interpret experiment results Understanding of data modeling, data infrastructure, and statistical and machine learning Ability to understand and speak the language of data scientists and data engineers to be at the leading edge of the fast moving data landscape through experience with tools such as: Modern BI / Analytics tools such as Microstrategy or Tableau R or related languages/frameworks AI and ML frameworks and tools Experience playing the product owner role of an engineering team Lean business development and customer development experience Strong written and verbal communication skills Our Core Values: Respect, Honesty, and Integrity for All Stakeholders Always be Learning Relentless Focus on the Customer Never be Satisfied Create Value Seek Accountability and Ownership Vibes is an equal opportunity employer that encourages and fosters diversity in the workplace. We offer a career building experience in a fast-paced organization and industry."

# %%
for i in range(len(df)):
    s = cleanhtml(df.loc[i,'Job Description'])
    s = remove(s)
    s.strip()
    
    words = word_tokenize(s)
#     stemmed_sentence = reduce(lambda x, y: x + " " + ps.stem(y), words, "")
#     words = word_tokenize(stemmed_sentence)
    filtered_sentence = [w for w in words if not w.lower() in stop_words]
    
    df.loc[i,'Job Description'] = ' '.join(filtered_sentence)

# %%
df.loc[2,'Job Description']
# Out:
# "Product Manager - Unique opportunity mobile marketing leader Vibes helps brands unlock new revenue arming technology expertise need succeed mobile marketing . group passionate technologists , intent solving hard problems evolving world mobile engagement . focus collaboration continuous improvement products . Product Manager passion data creating amazing customer experiences connect people brands love . experience delivering successful , data informed SaaS experiences excited Data experience continue making key differentiator platform . energized setting vision , experimenting validate invalidate assumptions , leading product experience team build software interact millions people via phones . Responsibilities Define data strategy platform Manage product development strategy lean hypotheses & amp ; experimentation , defining customer experiences journeys , owning managing product backlog Lead team take potential data , models , outputs integrate current platform experience potential new experiences Work Data & amp ; Analytics engineering team build predictive prescriptive data intelligence Mobile Engagement platform Collaborate Marketing , Sales , Customer Success Technology understand feasibility constraints potential alternative solutions Communicate team 's accomplishments upward outward throughout organization compelling market-facing voice Vibes ' data vision experiences Requirements 2+ years relevant product management experience , strongly preferred Ability analyze data , write SQL , interpret experiment results Understanding data modeling , data infrastructure , statistical machine learning Ability understand speak language data scientists data engineers leading edge fast moving data landscape experience tools : Modern BI / Analytics tools Microstrategy Tableau R related languages/frameworks AI ML frameworks tools Experience playing product owner role engineering team Lean business development customer development experience Strong written verbal communication skills Core Values : Respect , Honesty , Integrity Stakeholders Always Learning Relentless Focus Customer Never Satisfied Create Value Seek Accountability Ownership Vibes equal opportunity employer encourages fosters diversity workplace . offer career building experience fast-paced organization industry ."

# %%
tfidf = TfidfVectorizer()
X_tfidf = tfidf.fit_transform(df['Job Description']).toarray()
vocab = tfidf.vocabulary_
reverse_vocab = {v:k for k,v in vocab.items()}
feature_names = tfidf.get_feature_names_out()
df_tfidf = pd.DataFrame(X_tfidf, columns = feature_names)
idx = X_tfidf.argsort(axis=1)

# %%
tfidf_max2 = idx[:,-2:]

# %%
print ([[(reverse_vocab.get(item), X_tfidf[i, item])  for item in row] 
                     for i, row in enumerate(tfidf_max2) ])
# Out:
# [[('guest', 0.25332621432566116), ('gm', 0.25637564878519087)], [('ability', 0.16858466136763411), ('restaurant', 0.4020204988382898)], [('vibes', 0.3564793327079397), ('data', 0.3703716636710829)], [('office', 0.3442380838581034), ('agents', 0.41892226987662323)], [('print', 0.3799754850936955), ('copy', 0.41091082624901526)], [('risk', 0.48552517601231554), ('cyber', 0.6481255469833854)], [('nutritional', 0.2957297713165688), ('gnc', 0.45691607578490395)], [('bank', 0.3944401918562681), ('mortgage', 0.419924831280332)], [('property', 0.24980481166536395), ('prg', 0.43132327691750943)], [('cannabis', 0.3138122532280034), ('gti', 0.5465968299726927)], [('copywriter', 0.24369819045420005), ('hcp', 0.2444904438